# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(15, 8))

ax.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])

year_span = np.arange(df['Year'].min(), 2051)

regr = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
ax.plot(year_span, regr.slope * year_span + regr.intercept)

df_newer = df[df['Year'] >= 2000]
year_span_newer = np.arange(2000, 2051)

regr_newer = linregress(df_newer['Year'], df_newer['CSIRO Adjusted Sea Level'])
ax.plot(year_span_newer, regr_newer.slope * year_span_newer + regr_newer.intercept, 'r')

ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Rise in Sea Level')

plt.show()

# %%
df_newer = df[df['Year'] >= 2000]
df_newer
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 120  2000                  7.062992           6.791339           7.334646
# 121  2001                  7.287402           7.019685           7.555118
# 122  2002                  7.381890           7.110236           7.653543
# 123  2003                  7.759843           7.484252           8.035433
# 124  2004                  7.740157           7.464567           8.015748
# 125  2005                  7.744094           7.472441           8.015748
# 126  2006                  7.917323           7.645669           8.188976
# 127  2007                  7.996063           7.712598           8.279528
# 128  2008                  8.350394           8.078740           8.622047
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 120                 6.920582
# 121                 7.087460
# 122                 7.319698
# 123                 7.488353
# 124                 7.507933
# 125                 7.644563
# 126                 7.697420
# 127                 7.702147
# 128                 7.907365
# 129                 8.046354
# 130                 8.122973
# 131                 8.053065
# 132                 8.457058
# 133                 8.546648

# %%
fig, ax = plt.subplots(figsize=(15, 8))

ax.scatter(df_newer['Year'], df_newer['CSIRO Adjusted Sea Level'])

year_span = np.arange(df_newer['Year'].min(), 2051)

regr_newer = linregress(df_newer['Year'], df_newer['CSIRO Adjusted Sea Level'])
ax.plot(year_span, regr_newer.slope * year_span + regr_newer.intercept, 'r')

ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Rise in Sea Level')

plt.show()
